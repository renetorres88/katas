# %% [markdown]
# # Manual de la Nave

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (7.6.5)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipywidgets) (6.9.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipywidgets) (8.0.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: black in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipython>=4.0.0->ipywidgets) (22.1.0)
# Requirement already satisfied: backcall in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.28)
# Requirement already satisfied: stack-data in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipython>=4.0.0->ipywidgets) (0.1.4)
# Requirement already satisfied: decorator in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pygments in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: pickleshare in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from ipython>=4.0.0->ipywidgets) (58.1.0)
# Requirement already satisfied: colorama in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: jupyter-core in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from nbformat>=4.2.0->ipywidgets) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets) (303)
# Requirement already satisfied: nbconvert in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.4.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.5)
# Requirement already satisfied: jinja2 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: prometheus-client in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from black->ipython>=4.0.0->ipywidgets) (0.9.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from black->ipython>=4.0.0->ipywidgets) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from black->ipython>=4.0.0->ipywidgets) (0.4.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from black->ipython>=4.0.0->ipywidgets) (8.0.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from black->ipython>=4.0.0->ipywidgets) (2.5.0)
# Requirement already satisfied: asttokens in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: executing in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: pywinpty<1,>=0.5 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: testpath in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.10)
# Requirement already satisfied: jupyterlab-pygments in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: bleach in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: pycparser in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.7)

# %%
import ipywidgets as widgets

ignition = widgets.ToggleButton(
    value=False,
    description='Iniciar Launch',
    button_style='success',
    tooltip='Engage your Launch',
    icon='rocket'
)

output = widgets.Output()

display(ignition, output)

def on_value_change(change):
    with output:
        if change['new'] == True:
            print("Nave Iniciada!")
        else:   
            print("Nave Detenida")

ignition.observe(on_value_change, names='value')
# Out:
# ToggleButton(value=False, button_style='success', description='Iniciar Launch', icon='rocket', tooltip='Engage…
# Output()

# %%
 # %pip install matplotlib
 # %pip install numpy
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   × Building wheel for numpy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [201 lines of output]
#       Running from numpy source directory.
#       Cythonizing sources
#       Processing numpy/random\_bounded_integers.pxd.in
#       Processing numpy/random\bit_generator.pyx
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-fiufllfs\numpy_bbf9cef0562346869146f776e1fda8e4\tools\cythonize.py:63: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#         from distutils.version import LooseVersion
#       Processing numpy/random\mtrand.pyx
#       Processing numpy/random\_bounded_integers.pyx.in
#       Processing numpy/random\_common.pyx
#       Processing numpy/random\_generator.pyx
#       Processing numpy/random\_mt19937.pyx
#       Processing numpy/random\_pcg64.pyx
#       Processing numpy/random\_philox.pyx
#       Processing numpy/random\_sfc64.pyx
#       INFO: blas_opt_info:
#       INFO: blas_armpl_info:
#       INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       INFO: customize MSVCCompiler
#       INFO:   libraries armpl_lp64_mp not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: blas_mkl_info:
#       INFO:   libraries mkl_rt not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: blis_info:
#       INFO:   libraries blis not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_info:
#       INFO:   libraries openblas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO: get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       INFO: customize GnuFCompiler
#       WARN: Could not locate executable g77
#       WARN: Could not locate executable f77
#       INFO: customize IntelVisualFCompiler
#       WARN: Could not locate executable ifort
#       WARN: Could not locate executable ifl
#       INFO: customize AbsoftFCompiler
#       WARN: Could not locate executable f90
#       INFO: customize CompaqVisualFCompiler
#       WARN: Could not locate executable DF
#       INFO: customize IntelItaniumVisualFCompiler
#       WARN: Could not locate executable efl
#       INFO: customize Gnu95FCompiler
#       WARN: Could not locate executable gfortran
#       WARN: Could not locate executable f95
#       INFO: customize G95FCompiler
#       WARN: Could not locate executable g95
#       INFO: customize IntelEM64VisualFCompiler
#       INFO: customize IntelEM64TFCompiler
#       WARN: Could not locate executable efort
#       WARN: Could not locate executable efc
#       INFO: customize PGroupFlangCompiler
#       WARN: Could not locate executable flang
#       WARN: don't know how to compile Fortran code on platform 'nt'
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: accelerate_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_blas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries tatlas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_blas_info:
#       INFO:   libraries satlas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_blas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_blas_info:
#       INFO:   libraries f77blas,cblas,atlas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-fiufllfs\numpy_bbf9cef0562346869146f776e1fda8e4\numpy\distutils\system_info.py:2077: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         if self._calc_info(blas):
#       INFO: blas_info:
#       INFO:   libraries blas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-fiufllfs\numpy_bbf9cef0562346869146f776e1fda8e4\numpy\distutils\system_info.py:2077: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         if self._calc_info(blas):
#       INFO: blas_src_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-fiufllfs\numpy_bbf9cef0562346869146f776e1fda8e4\numpy\distutils\system_info.py:2077: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         if self._calc_info(blas):
#       INFO:   NOT AVAILABLE
#       INFO:
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       INFO: lapack_opt_info:
#       INFO: lapack_armpl_info:
#       INFO:   libraries armpl_lp64_mp not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: lapack_mkl_info:
#       INFO:   libraries mkl_rt not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_lapack_info:
#       INFO:   libraries openblas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_clapack_info:
#       INFO:   libraries openblas,lapack not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: flame_info:
#       INFO:   libraries flame not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries tatlas,tatlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib
#       INFO:   libraries tatlas,tatlas not found in C:\
#       INFO:   libraries tatlas,tatlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\libs
#       INFO: <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_info:
#       INFO:   libraries satlas,satlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib
#       INFO:   libraries satlas,satlas not found in C:\
#       INFO:   libraries satlas,satlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\libs
#       INFO: <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\libs
#       INFO: <class 'numpy.distutils.system_info.atlas_threads_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_info:
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib
#       INFO:   libraries f77blas,cblas,atlas not found in C:\
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\libs
#       INFO: <class 'numpy.distutils.system_info.atlas_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: lapack_info:
#       INFO:   libraries lapack not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-fiufllfs\numpy_bbf9cef0562346869146f776e1fda8e4\numpy\distutils\system_info.py:1902: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         return getattr(self, '_calc_info_{}'.format(name))()
#       INFO: lapack_src_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-fiufllfs\numpy_bbf9cef0562346869146f776e1fda8e4\numpy\distutils\system_info.py:1902: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         return getattr(self, '_calc_info_{}'.format(name))()
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: numpy_linalg_lapack_lite:
#       INFO:   FOUND:
#       INFO:     language = c
#       INFO:
#       Warning: attempted relative import with no known parent package
#       C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running config_cc
#       INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       INFO: build_src
#       INFO: building py_modules sources
#       creating build
#       creating build\src.win32-3.10
#       creating build\src.win32-3.10\numpy
#       creating build\src.win32-3.10\numpy\distutils
#       INFO: building library "npymath" sources
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
#   Using cached matplotlib-3.5.1-cp310-cp310-win32.whl (7.1 MB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.2-cp310-cp310-win32.whl (42 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from matplotlib) (3.0.7)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.29.1-py3-none-any.whl (895 kB)
# Collecting numpy>=1.17
#   Using cached numpy-1.22.2.zip (11.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: packaging>=20.0 in c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from matplotlib) (2.8.2)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.0.1-cp310-cp310-win32.whl (2.8 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\eleaquim\appdata\roaming\python\python310-32\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml): started
#   Building wheel for numpy (pyproject.toml): finished with status 'error'
# Failed to build numpy
# Collecting numpy
#   Using cached numpy-1.22.2.zip (11.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml): started
#   Building wheel for numpy (pyproject.toml): finished with status 'error'
# Failed to build numpy
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   × Building wheel for numpy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [201 lines of output]
#       Running from numpy source directory.
#       Cythonizing sources
#       Processing numpy/random\_bounded_integers.pxd.in
#       Processing numpy/random\bit_generator.pyx
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-_4vnv0i1\numpy_267767f23bd142af96a61a29b987ffbb\tools\cythonize.py:63: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#         from distutils.version import LooseVersion
#       Processing numpy/random\mtrand.pyx
#       Processing numpy/random\_bounded_integers.pyx.in
#       Processing numpy/random\_common.pyx
#       Processing numpy/random\_generator.pyx
#       Processing numpy/random\_mt19937.pyx
#       Processing numpy/random\_pcg64.pyx
#       Processing numpy/random\_philox.pyx
#       Processing numpy/random\_sfc64.pyx
#       INFO: blas_opt_info:
#       INFO: blas_armpl_info:
#       INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       INFO: customize MSVCCompiler
#       INFO:   libraries armpl_lp64_mp not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: blas_mkl_info:
#       INFO:   libraries mkl_rt not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: blis_info:
#       INFO:   libraries blis not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_info:
#       INFO:   libraries openblas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO: get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       INFO: customize GnuFCompiler
#       WARN: Could not locate executable g77
#       WARN: Could not locate executable f77
#       INFO: customize IntelVisualFCompiler
#       WARN: Could not locate executable ifort
#       WARN: Could not locate executable ifl
#       INFO: customize AbsoftFCompiler
#       WARN: Could not locate executable f90
#       INFO: customize CompaqVisualFCompiler
#       WARN: Could not locate executable DF
#       INFO: customize IntelItaniumVisualFCompiler
#       WARN: Could not locate executable efl
#       INFO: customize Gnu95FCompiler
#       WARN: Could not locate executable gfortran
#       WARN: Could not locate executable f95
#       INFO: customize G95FCompiler
#       WARN: Could not locate executable g95
#       INFO: customize IntelEM64VisualFCompiler
#       INFO: customize IntelEM64TFCompiler
#       WARN: Could not locate executable efort
#       WARN: Could not locate executable efc
#       INFO: customize PGroupFlangCompiler
#       WARN: Could not locate executable flang
#       WARN: don't know how to compile Fortran code on platform 'nt'
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: accelerate_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_blas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries tatlas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_blas_info:
#       INFO:   libraries satlas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_blas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_blas_info:
#       INFO:   libraries f77blas,cblas,atlas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-_4vnv0i1\numpy_267767f23bd142af96a61a29b987ffbb\numpy\distutils\system_info.py:2077: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         if self._calc_info(blas):
#       INFO: blas_info:
#       INFO:   libraries blas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-_4vnv0i1\numpy_267767f23bd142af96a61a29b987ffbb\numpy\distutils\system_info.py:2077: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         if self._calc_info(blas):
#       INFO: blas_src_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-_4vnv0i1\numpy_267767f23bd142af96a61a29b987ffbb\numpy\distutils\system_info.py:2077: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         if self._calc_info(blas):
#       INFO:   NOT AVAILABLE
#       INFO:
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       INFO: lapack_opt_info:
#       INFO: lapack_armpl_info:
#       INFO:   libraries armpl_lp64_mp not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: lapack_mkl_info:
#       INFO:   libraries mkl_rt not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_lapack_info:
#       INFO:   libraries openblas not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_clapack_info:
#       INFO:   libraries openblas,lapack not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: flame_info:
#       INFO:   libraries flame not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries tatlas,tatlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib
#       INFO:   libraries tatlas,tatlas not found in C:\
#       INFO:   libraries tatlas,tatlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\libs
#       INFO: <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_info:
#       INFO:   libraries satlas,satlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib
#       INFO:   libraries satlas,satlas not found in C:\
#       INFO:   libraries satlas,satlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\libs
#       INFO: <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\libs
#       INFO: <class 'numpy.distutils.system_info.atlas_threads_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_info:
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib
#       INFO:   libraries f77blas,cblas,atlas not found in C:\
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\libs
#       INFO: <class 'numpy.distutils.system_info.atlas_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: lapack_info:
#       INFO:   libraries lapack not found in ['C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\lib', 'C:\\', 'C:\\Users\\Eleaquim\\AppData\\Local\\Programs\\Python\\Python310-32\\libs']
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-_4vnv0i1\numpy_267767f23bd142af96a61a29b987ffbb\numpy\distutils\system_info.py:1902: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         return getattr(self, '_calc_info_{}'.format(name))()
#       INFO: lapack_src_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\Eleaquim\AppData\Local\Temp\pip-install-_4vnv0i1\numpy_267767f23bd142af96a61a29b987ffbb\numpy\distutils\system_info.py:1902: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         return getattr(self, '_calc_info_{}'.format(name))()
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: numpy_linalg_lapack_lite:
#       INFO:   FOUND:
#       INFO:     language = c
#       INFO:
#       Warning: attempted relative import with no known parent package
#       C:\Users\Eleaquim\AppData\Local\Programs\Python\Python310-32\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running config_cc
#       INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       INFO: build_src
#       INFO: building py_modules sources
#       creating build
#       creating build\src.win32-3.10
#       creating build\src.win32-3.10\numpy
#       creating build\src.win32-3.10\numpy\distutils
#       INFO: building library "npymath" sources
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\eleaquim\appdata\local\programs\python\python310-32\lib\site-packages)

# %% [markdown]
# ## Niveles de Oxígeno
#
# Muestra diez minutos de niveles de oxígeno en tu nave.

# %%
   import numpy as np
    import matplotlib.pyplot as plt
    data = np.random.default_rng(12345)
    oxy_nums = data.integers(low=0, high=10, size=10)

    plt.bar(range(len(oxy_nums)), oxy_nums)
    plt.show()
# Out:
#   Input In [34]
#     import matplotlib.pyplot as plt
#     ^
# IndentationError: unexpected indent
